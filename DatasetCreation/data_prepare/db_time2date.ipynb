# %%
import json

with open('/Users/tranxuanhuy/Documents/Viettel Digital Talent/Chatbot/Code/data_creation/db_train_5/sample.jsonl') as f:
    sample = list(f)

# %%
input = sample[6]
input = json.loads(input)
input = {i:input[i] for i in ['CHU KỲ THỜI GIAN', 'THỨ', 'NGÀY', 'TUẦN', 'THÁNG', 'QUÝ', 'NĂM']}
input
# Out:
# {'CHU KỲ THỜI GIAN': 'tháng',
#  'THỨ': 'khác',
#  'NGÀY': 'khác',
#  'TUẦN': 'khác',
#  'THÁNG': 'này',
#  'QUÝ': 'khác',
#  'NĂM': 'khác'}

# %%
import pandas as pd
df = pd.DataFrame([json.loads(x) for x in sample])
df['Date'] = df.apply(time2date, axis=1)
check = df[['ĐƠN VỊ', 'CHU KỲ THỜI GIAN', 'THỨ', 'NGÀY', 'TUẦN', 'THÁNG', 'QUÝ', 'NĂM', 'Date']]
check
# Out:
#      ĐƠN VỊ CHU KỲ THỜI GIAN   THỨ     NGÀY      TUẦN THÁNG   QUÝ   NĂM  \
# 0        td             ngày  khác  hôm nay      khác  khác  khác  khác
# 1        td             ngày  khác  hôm nay      khác  khác  khác  khác
# 2        td             ngày  khác  hôm nay      khác  khác  khác  khác
# 3        td             ngày     3     khác      khác  khác  khác  khác
# 4        td             ngày  khác  hôm nay      khác  khác  khác  khác
# ...     ...              ...   ...      ...       ...   ...   ...   ...
# 6765    vts             ngày     4     khác       sau  khác  khác  khác
# 6766    vts             ngày     5     khác       sau  khác  khác  khác
# 6767    vts             ngày     3     khác      khác  khác  khác  khác
# 6768    vts             ngày     2     khác       này  khác  khác  khác
# 6769    vts             ngày     7     khác  gần nhất  khác  khác  khác
#
#             Date
# 0     2023-08-29
# 1     2023-08-29
# 2     2023-08-29
# 3     2023-08-22
# 4     2023-08-29
# ...          ...
# 6765  2023-09-06
# 6766  2023-09-07
# 6767  2023-08-22
# 6768  2023-08-28
# 6769  2023-08-26
#
# [6770 rows x 9 columns]

# %%
check[(check['CHU KỲ THỜI GIAN']=='tháng') & (check['THỨ']=='chủ nhật')]
# Out:
# Empty DataFrame
# Columns: [CHU KỲ THỜI GIAN, THỨ, NGÀY, TUẦN, THÁNG, QUÝ, NĂM, Date]
# Index: []

# %%
df
# Out:
#      LOẠI BIỂU ĐỒ ĐƠN VỊ CHU KỲ THỜI GIAN   THỨ     NGÀY   TUẦN THÁNG   QUÝ  \
# 0       dashboard     td             ngày  khác  hôm nay   khác  khác  khác
# 1       dashboard     td             ngày  khác  hôm nay   khác  khác  khác
# 2         biểu đồ     td             ngày  khác  hôm nay   khác  khác  khác
# 3         biểu đồ     td             ngày  khác      mai   khác  khác  khác
# 4            khác     td             ngày  khác  hôm nay   khác  khác  khác
# ...           ...    ...              ...   ...      ...    ...   ...   ...
# 6765    dashboard    vts             ngày  khác     khác    này  khác  khác
# 6766      biểu đồ    vts             ngày     5     khác    sau  khác  khác
# 6767    dashboard    vts             ngày     6     khác  trước  khác  khác
# 6768         khác    vts             ngày  khác      kia   khác  khác  khác
# 6769      biểu đồ    vts             ngày  khác     khác  trước  khác  khác
#
#        NĂM        Date
# 0     khác  2023-08-28
# 1     khác  2023-08-28
# 2     khác  2023-08-28
# 3     khác  2023-08-29
# 4     khác  2023-08-28
# ...    ...         ...
# 6765  khác  2023-09-03
# 6766  khác  2023-09-07
# 6767  khác  2023-08-25
# 6768  khác  2023-08-30
# 6769  khác  2023-08-27
#
# [6770 rows x 10 columns]

# %%
check['THỨ'].loc[48]
# Out:
# 'chủ nhật'

# %%
input['NGÀY'] = 30

# %%
import datetime

# Get the current date
current_date = datetime.date.today()
print("Current Date:", current_date)

# Get the day of the week (0 = Monday, 6 = Sunday)
day_of_week = current_date.weekday()
print("Day of the Week:", day_of_week)
# Out:
# Current Date: 2023-08-29
# Day of the Week: 1

# %%
a = str(current_date)
a = a.replace('-', '').replace('-', '')
a
# Out:
# '20230829'

# %%
def time2date(input):
    chu_ky_thoi_gian = input['CHU KỲ THỜI GIAN']
    thu = input['THỨ']
    ngay = input['NGÀY']
    tuan = input['TUẦN']
    thang = input['THÁNG']
    quy = input['QUÝ']
    nam = input['NĂM']
    import datetime
    import calendar
    from dateutil.relativedelta import relativedelta
    current_date = datetime.date.today()
    if chu_ky_thoi_gian=='ngày':
# hôm kia
        if ngay=='hôm kia':
            output = current_date - datetime.timedelta(days=2)
# hôm qua
        elif ngay=='hôm qua':
            output = current_date - datetime.timedelta(days=1)
# hôm nay
        elif ngay=='hôm nay':
            output = current_date
# ngày mai
        elif ngay=='mai':
            output = current_date + datetime.timedelta(days=1)
# ngày kia
        elif ngay=='kia':
            output = current_date + datetime.timedelta(days=2)
# đầu
        elif ngay=='đầu':
            if thang=='trước':
                needed_thang = 12 if current_date.month==1 else current_date.month-1
                needed_nam = current_date.year-1 if current_date.month==1 else current_date.year
                output = datetime.date(
                    needed_nam, 
                    needed_thang, 
                    1
                )
            elif thang=='này':
                needed_thang = current_date.month
                needed_nam = current_date.year
                output = datetime.date(
                    needed_nam, 
                    needed_thang, 
                    1
                )
            elif thang=='sau':
                needed_thang = 1 if current_date.month==12 else current_date.month+1
                needed_nam = current_date.year+1 if current_date.month==12 else current_date.year
                output = datetime.date(
                    needed_nam, 
                    needed_thang, 
                    1
                )
# cuối
        elif ngay=='cuối':
            if thang=='trước':
                needed_thang = 12 if current_date.month==1 else current_date.month-1
                needed_nam = current_date.year-1 if current_date.month==1 else current_date.year
                output = datetime.date(
                    needed_nam, 
                    needed_thang, 
                    calendar.monthrange(needed_nam, needed_thang)[1]
                )
            elif thang=='này':
                needed_thang = current_date.month
                needed_nam = current_date.year
                output = datetime.date(
                    needed_nam, 
                    needed_thang, 
                    calendar.monthrange(needed_nam, needed_thang)[1]
                )
            elif thang=='sau':
                needed_thang = 1 if current_date.month==12 else current_date.month+1
                needed_nam = current_date.year+1 if current_date.month==12 else current_date.year
                output = datetime.date(
                    needed_nam, 
                    needed_thang, 
                    calendar.monthrange(needed_nam, needed_thang)[1]
                )
# xxx
        elif ngay.isdigit():
            ngay = int(ngay)
            if thang.isdigit():
                thang = int(thang)
                if nam.isdigit():
                    nam = int(nam)
                    try:
                        output = datetime.date(nam, thang, ngay)
                    except ValueError:
                        output = "Invalid"
                else:
                    try:
                        output = datetime.date(current_date.year, thang, ngay)
                    except ValueError:
                        output = "Invalid"
            else:
                try:
                    output = datetime.date(current_date.year, current_date.month, ngay) 
                except ValueError:
                    output = "Invalid"
        elif ngay=='khác':
# thứ hai tuần sau
# thứ hai tuần này
# thứ hai tuần trước
# thứ hai tuần gần nhất
# thứ hai   
            if thu != "khác":
                if tuan=='khác' or tuan=='gần nhất':
                    current_thu = current_date.weekday()+2
                    input_thu = 8 if thu=='chủ nhật' else int(thu)
                    if input_thu < current_thu:
                        daydelta = current_thu - input_thu
                        output = current_date - datetime.timedelta(days=daydelta)
                    elif input_thu == current_thu:
                        output = current_date - datetime.timedelta(days=7)
                    else:
                        daydelta = input_thu - current_thu
                        output = current_date - datetime.timedelta(days=7-daydelta)
                elif tuan=='này':
                    current_thu = current_date.weekday()+2
                    input_thu = 8 if thu=='chủ nhật' else int(thu)
                    if input_thu < current_thu:
                        daydelta = current_thu - input_thu
                        output = current_date - datetime.timedelta(days=daydelta)
                    elif input_thu == current_thu:
                        output = current_date
                    else:
                        daydelta = input_thu - current_thu
                        output = current_date + datetime.timedelta(days=daydelta)
                elif tuan=='trước':
                    current_thu = current_date.weekday()+2
                    input_thu = 8 if thu=='chủ nhật' else int(thu)
                    if input_thu < current_thu:
                        daydelta = current_thu - input_thu + 7
                        output = current_date - datetime.timedelta(days=daydelta)
                    elif input_thu == current_thu:
                        output = current_date - datetime.timedelta(days=7)
                    else:
                        daydelta = input_thu - current_thu
                        output = current_date - datetime.timedelta(days=7-daydelta)
                elif tuan=='sau':
                    current_thu = current_date.weekday()+2
                    input_thu = 8 if thu=='chủ nhật' else int(thu)
                    if input_thu < current_thu:
                        daydelta = 7 - (current_thu - input_thu)
                        output = current_date + datetime.timedelta(days=daydelta)
                    elif input_thu == current_thu:
                        output = current_date + datetime.timedelta(days=7)
                    else:
                        daydelta = input_thu - current_thu
                        output = current_date + datetime.timedelta(days=7+daydelta)
            elif thu=='khác':
                current_thu = current_date.weekday()
                if tuan=='trước' or tuan=='gần nhất': # ngày cuối tuần
                    daydelta = current_thu+1
                    output = current_date - datetime.timedelta(days=daydelta)
                elif tuan=='này':
                    daydelta = 6 - current_thu
                    if daydelta > 0:
                        output = current_date + datetime.timedelta(days=daydelta)
                    else:
                        output = current_date
                elif tuan=='sau':
                    daydelta = 13 - current_thu
                    output = current_date + datetime.timedelta(days=daydelta)
        else:
            print('Error chu ky thoi gian: ngay')
        
    elif chu_ky_thoi_gian=='tháng': # ngày cuối tháng
        if thu != 'khác' or ngay != 'khác' or tuan != 'khác':
            output = 'Invalid'
        elif thang=='trước':
            needed_thang = 12 if current_date.month==1 else current_date.month-1
            needed_nam = current_date.year-1 if current_date.month==1 else current_date.year
            output = datetime.date(
                needed_nam, 
                needed_thang, 
                calendar.monthrange(needed_nam, needed_thang)[1]
            )
        elif thang=='này':
            needed_thang = current_date.month
            needed_nam = current_date.year
            output = datetime.date(
                needed_nam, 
                needed_thang, 
                calendar.monthrange(needed_nam, needed_thang)[1]
            )
        elif thang=='sau':
            needed_thang = 1 if current_date.month==12 else current_date.month+1
            needed_nam = current_date.year+1 if current_date.month==12 else current_date.year
            output = datetime.date(
                needed_nam, 
                needed_thang, 
                calendar.monthrange(needed_nam, needed_thang)[1]
            )
        elif thang.isdigit():
            thang = int(thang)
            if nam.isdigit():
                nam = int(nam)
                output = datetime.date(
                    int(nam), 
                    int(thang), 
                    calendar.monthrange(int(nam), int(thang))[1]
                )
            elif nam =='khác':
                if thang > current_date.month:
                    output = datetime.date(
                        current_date.year-1, 
                        thang, 
                        calendar.monthrange(current_date.year-1, thang)[1]
                    )
                else:
                    output = datetime.date(
                        current_date.year, 
                        thang, 
                        calendar.monthrange(current_date.year, thang)[1]
                    )
        elif thang=='khác':
            needed_thang = 12 if current_date.month==1 else current_date.month-1
            needed_nam = current_date.year-1 if current_date.month==1 else current_date.year
            output = datetime.date(
                needed_nam, 
                needed_thang, 
                calendar.monthrange(needed_nam, needed_thang)[1]
            )
        else:
            print('Error chu ky thoi gian: thang')
    elif chu_ky_thoi_gian=='quý':
        if quy in ['1', '2', '3', '4', 'I', 'II', 'III', 'IV']:
            output = "Valid"
            # print('Chu ky thoi gian: quy ' + quy)
        else:
            output = "Invalid"
            # print('Error chu ky thoi gian: quy')
    elif chu_ky_thoi_gian=='năm':
        if nam.isdigit():
            output = "Valid"
            # print("Chu ky thoi gian: nam " + nam)
        else:
            output = "Invalid"
            # print('Error chu ky thoi gian: năm')
    elif chu_ky_thoi_gian=='khác':
        output = "Valid"
    return output

# output = time2date(input)
# output

# %%
for input in sample:
    try:
        output = time2date(json.loads(input))
    except:
        print(json.loads(input))
        break

output = time2date(json.loads(input))

# %%
time2dictnonum = {
    # ngày theo tuần
    'thứ 2': {'thứ': '2', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 3': {'thứ': '3', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 4': {'thứ': '4', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 5': {'thứ': '5', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 6': {'thứ': '6', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 7': {'thứ': '7', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},

    'thứ hai': {'thứ': '2', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba': {'thứ': '3', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư': {'thứ': '4', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm': {'thứ': '5', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu': {'thứ': '6', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy': {'thứ': '7', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},

    # ngày so với hôm nay
    # ---
    'hôm kia': {'thứ': '', 'ngày': 'hôm kia', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'hôm qua': {'thứ': '', 'ngày': 'hôm qua', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'hôm nay': {'thứ': '', 'ngày': 'hôm nay', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'ngày mai': {'thứ': '', 'ngày': 'mai', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'ngày kia': {'thứ': '', 'ngày': 'kia', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},

    # ngày theo tuần so với tuần này
    'thứ hai tuần sau': {'thứ': '2', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba tuần sau': {'thứ': '3', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư tuần sau': {'thứ': '4', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm tuần sau': {'thứ': '5', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu tuần sau': {'thứ': '6', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy tuần sau': {'thứ': '7', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật tuần sau': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},

    'thứ hai tuần này': {'thứ': '2', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba tuần này': {'thứ': '3', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư tuần này': {'thứ': '4', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm tuần này': {'thứ': '5', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu tuần này': {'thứ': '6', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy tuần này': {'thứ': '7', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật tuần này': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},

    'thứ hai tuần trước': {'thứ': '2', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba tuần trước': {'thứ': '3', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư tuần trước': {'thứ': '4', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm tuần trước': {'thứ': '5', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu tuần trước': {'thứ': '6', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy tuần trước': {'thứ': '7', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật tuần trước': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    
    'thứ hai tuần gần nhất': {'thứ': '2', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba tuần gần nhất': {'thứ': '3', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư tuần gần nhất': {'thứ': '4', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm tuần gần nhất': {'thứ': '5', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu tuần gần nhất': {'thứ': '6', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy tuần gần nhất': {'thứ': '7', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật tuần gần nhất': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},

    # ngày theo tháng so với tháng hiện tại
    'ngày đầu tháng này': {'thứ': '', 'ngày': 'đầu', 'tuần': '', 'tháng': 'này', 'quý': '', 'năm': ''},
    'ngày cuối tháng này': {'thứ': '', 'ngày': 'cuối', 'tuần': '', 'tháng': 'này', 'quý': '', 'năm': ''},
    'ngày đầu tháng sau': {'thứ': '', 'ngày': 'đầu', 'tuần': '', 'tháng': 'sau', 'quý': '', 'năm': ''},
    'ngày cuối tháng sau': {'thứ': '', 'ngày': 'cuối', 'tuần': '', 'tháng': 'sau', 'quý': '', 'năm': ''},
    'ngày đầu tháng trước': {'thứ': '', 'ngày': 'đầu', 'tuần': '', 'tháng': 'trước', 'quý': '', 'năm': ''},
    'ngày cuối tháng trước': {'thứ': '', 'ngày': 'cuối', 'tuần': '', 'tháng': 'trước', 'quý': '', 'năm': ''},

    # tuần so với tuần hiện tại
    'tuần trước': {'thứ': '', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'tuần này': {'thứ': '', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'tuần sau': {'thứ': '', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},


    # tháng so với tháng hiện tại
    'tháng trước': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'trước', 'quý': '', 'năm': ''},
    'tháng này': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'này', 'quý': '', 'năm': ''},
    'tháng sau': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'sau', 'quý': '', 'năm': ''},
}


time2dictwithnum = {
    ## ngày
    # xxx/yyy/zzz
    'ngày xxx tháng yyy năm zzz': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    'xxx/yyy/zzz': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    'zzz/yyy/xxx': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    
    # xxx/yyy
    'ngày xxx tháng yyy': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': ''},
    'xxx/yyy': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': ''},

    # xxx
    'ngày xxx': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},

    ## tháng
    # yyy/zzz
    'tháng yyy năm zzz':  {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    'yyy/zzz': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    'zzz/yyy': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},

    # yyy
    'tháng yyy':  {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': ''},

    ## quý
    # ttt/zzz
    'quý ttt năm zzz': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': 'ttt', 'năm': 'zzz'},

    # ttt
    'quý ttt': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': 'ttt', 'năm': ''},

    ## năm
    # zzz
    'năm zzz':  {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': 'zzz'},
}
