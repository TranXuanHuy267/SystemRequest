# %%
import json

with open("/Users/tranxuanhuy/Documents/Viettel Digital Talent/Chatbot/Code/data_creation/url2shortestdonvi.json", 'r') as f:
    url2shortestdonvi = json.load(f)

output_donvi = list(set(url2shortestdonvi.values()))

# %%
output_donvi[60:90]
# Out:
# ['hgg',
#  'bgg',
#  'hnm',
#  'vpc',
#  'vtsport',
#  'tha',
#  'nat',
#  'qbh',
#  'tỉnh/tp',
#  'pyn',
#  'stg',
#  'tbh',
#  'idc',
#  'vtx',
#  'gli',
#  'vtt',
#  'hải phòng',
#  'kgg',
#  'long an',
#  'hth',
#  'cto',
#  'bdh',
#  'ybi',
#  'n',
#  'ndh',
#  'vdtc',
#  'nbh',
#  'tqg',
#  'hni',
#  'tgg']

# %%
import pandas as pd
with open('/Users/tranxuanhuy/Documents/Viettel Digital Talent/Chatbot/Code/data_creation/db_train_2/sample.jsonl', 'r') as f:
    sample = list(f)

sample = [json.loads(i) for i in sample]
sample = pd.DataFrame(sample)
sample
# Out:
#      LOẠI BIỂU ĐỒ ĐƠN VỊ CHU KỲ THỜI GIAN
# 0         biểu đồ     td             ngày
# 1         biểu đồ     td             ngày
# 2       dashboard     td             ngày
# 3         biểu đồ     td             ngày
# 4            khác     td             ngày
# ...           ...    ...              ...
# 6785    dashboard    vts             ngày
# 6786         khác    vts             ngày
# 6787      biểu đồ    vts             ngày
# 6788      biểu đồ    vts             ngày
# 6789    dashboard    vts             ngày
#
# [6790 rows x 3 columns]

# %%
sample[sample['ĐƠN VỊ']=='hải phòng']
# Out:
#      LOẠI BIỂU ĐỒ     ĐƠN VỊ CHU KỲ THỜI GIAN
# 2425         khác  hải phòng             ngày
# 2426      biểu đồ  hải phòng             ngày
# 2427    dashboard  hải phòng             ngày
# 2428         khác  hải phòng             ngày
# 2429      biểu đồ  hải phòng             ngày
# 5975    dashboard  hải phòng             ngày
# 5976      biểu đồ  hải phòng             ngày
# 5977      biểu đồ  hải phòng             ngày
# 5978    dashboard  hải phòng             ngày
# 5979    dashboard  hải phòng             ngày

# %%
sample[sample['ĐƠN VỊ']=='hpg']
# Out:
#      LOẠI BIỂU ĐỒ ĐƠN VỊ CHU KỲ THỜI GIAN
# 205          khác    hpg            tháng
# 206          khác    hpg            tháng
# 207     dashboard    hpg            tháng
# 208          khác    hpg            tháng
# 209     dashboard    hpg            tháng
# 400     dashboard    hpg            tháng
# 401     dashboard    hpg            tháng
# 402       biểu đồ    hpg            tháng
# 403     dashboard    hpg            tháng
# 404          khác    hpg            tháng
# 1475      biểu đồ    hpg            tháng
# 1476         khác    hpg            tháng
# 1477         khác    hpg            tháng
# 1478    dashboard    hpg            tháng
# 1479    dashboard    hpg            tháng
# 1480      biểu đồ    hpg             ngày
# 1481         khác    hpg             ngày
# 1482    dashboard    hpg             ngày
# 1483         khác    hpg             ngày
# 1484    dashboard    hpg             ngày
# 2420      biểu đồ    hpg            tháng
# ...

# %%
generate_db_1 = pd.read_csv("/Users/tranxuanhuy/Documents/Viettel Digital Talent/Chatbot/Code/data_creation/generate_db_1.csv")
generate_db_1[generate_db_1['đơn vị']=='kon tum']
# Out:
#       Unnamed: 0                                   câu lệnh sinh ra   đơn vị  \
# 2435        2435                 ngày hôm nay tôi đã mở của kon tum  kon tum
# 2436        2436  kon tum chắc chắn sẽ có một ngày tuyệt vời khi...  kon tum
# 2437        2437  để hiểu rõ hơn về tình hình, tôi đã mở biểu đồ...  kon tum
# 2438        2438  tôi muốn biết tình hình ở kon tum hôm nay nên ...  kon tum
# 2439        2439  mở của kon tum là một việc cần thiết mỗi ngày ...  kon tum
# 2440        2440  hãy mở biểu đồ để theo dõi tổng quan tình hình...  kon tum
# 2441        2441  cần phải mở biểu đồ kết hợp đường và cột để ki...  kon tum
# 2442        2442  hãy mở biểu đồ đường để xem tổng quan tình hìn...  kon tum
# 2443        2443  khi mở biểu đồ cơ cấu, có thể xem được dữ liệu...  kon tum
# 2444        2444  tại hội nghị, cần mở đát bót để trình bày thàn...  kon tum
#
#      chu kỳ thời gian đơn vị (viết tắt)                 URL  \
# ...

# %%
generate_db_1[generate_db_1['URL']=='/pages/screen/6436']
# Out:
#       Unnamed: 0                                   câu lệnh sinh ra  \
# 2435        2435                 ngày hôm nay tôi đã mở của kon tum
# 2436        2436  kon tum chắc chắn sẽ có một ngày tuyệt vời khi...
# 2437        2437  để hiểu rõ hơn về tình hình, tôi đã mở biểu đồ...
# 2438        2438  tôi muốn biết tình hình ở kon tum hôm nay nên ...
# 2439        2439  mở của kon tum là một việc cần thiết mỗi ngày ...
# 5985        5985         mở db của viettel kon tum vào ngày hôm nay
# 5986        5986  hãy mở biểu đồ kết hợp đường và cột của viette...
# 5987        5987  vui lòng mở biểu đồ thị phần của viettel kon t...
# 5988        5988  xin hãy mở db chỉ huy viettel kon tum vào ngày...
# 5989        5989  mở biểu đồ cảnh báo 2 của viettel kon tum vào ...
#
#                đơn vị chu kỳ thời gian đơn vị (viết tắt)                 URL  \
# 2435          kon tum             ngày           kon tum  /pages/screen/6436
# ...
