# %%
import pandas as pd
from copy import deepcopy
import random

prompt_dataset = pd.read_csv("/Users/tranxuanhuy/Documents/Viettel Digital Talent/Chatbot/Code/data_creation/generate_db_1.csv")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
prompt_dataset
# Out:
#       Unnamed: 0                                   câu lệnh sinh ra  \
# 0              0  hãy mở biểu đồ cơ cấu của tập đoàn trong ngày ...
# 1              1  trưởng phòng đã ra lệnh mở biểu đồ kết hợp đườ...
# 2              2  sáng nay, chúng ta sẽ mở đát bót chỉ huy của t...
# 3              3  truy cập biểu đồ cảnh báo 2 tập đoàn trong ngà...
# 4              4  quản lý yêu cầu mở cho tất cả nhân viên tập đo...
# ...          ...                                                ...
# 6785        6785  mở đát bọt việt solution ngày để truy cập các ...
# 6786        6786  hãy mở viettel solution ngày để kiểm tra tình ...
# 6787        6787  mở biểu đồ cột viettel solution ngày để xem bá...
# 6788        6788  hãy mở biểu đồ cơ cấu viettel solution ngày để...
# 6789        6789  mở dashboard viettel solution ngày để xem thôn...
#
#                 đơn vị chu kỳ thời gian đơn vị (viết tắt)                 URL  \
# 0             tập đoàn             ngày                td  /pages/screen/2354
# 1             tập đoàn             ngày                td  /pages/screen/2354
# 2             tập đoàn             ngày                td  /pages/screen/2354
# 3             tập đoàn             ngày                td  /pages/screen/2354
# 4             tập đoàn             ngày                td  /pages/screen/2354
# ...                ...              ...               ...                 ...
# 6785  viettel solution             ngày               vts  /pages/screen/3229
# 6786  viettel solution             ngày               vts  /pages/screen/3229
# 6787  viettel solution             ngày               vts  /pages/screen/3229
# 6788  viettel solution             ngày               vts  /pages/screen/3229
# 6789  viettel solution             ngày               vts  /pages/screen/3229
#
#            loại biểu đồ (chi tiết) loại biểu đồ
# 0                   biểu đồ cơ cấu      biểu đồ
# 1     biểu đồ kết hợp đường và cột      biểu đồ
# 2                  đát bót chỉ huy    dashboard
# 3               biểu đồ cảnh báo 2      biểu đồ
# 4                              NaN         khác
# ...                            ...          ...
# 6785                       đát bọt    dashboard
# 6786                           NaN         khác
# 6787                   biểu đồ cột      biểu đồ
# 6788                biểu đồ cơ cấu      biểu đồ
# 6789                     dashboard    dashboard
#
# [6790 rows x 8 columns]

# %%
need_dataset = prompt_dataset[['câu lệnh sinh ra', 'chu kỳ thời gian']]
need_dataset.loc[:, 'thời gian (chi tiết)'] = [""]*len(need_dataset)
need_dataset
# Out:
#                                        câu lệnh sinh ra chu kỳ thời gian  \
# 0     hãy mở biểu đồ cơ cấu của tập đoàn trong ngày ...             ngày
# 1     trưởng phòng đã ra lệnh mở biểu đồ kết hợp đườ...             ngày
# 2     sáng nay, chúng ta sẽ mở đát bót chỉ huy của t...             ngày
# 3     truy cập biểu đồ cảnh báo 2 tập đoàn trong ngà...             ngày
# 4     quản lý yêu cầu mở cho tất cả nhân viên tập đo...             ngày
# ...                                                 ...              ...
# 6785  mở đát bọt việt solution ngày để truy cập các ...             ngày
# 6786  hãy mở viettel solution ngày để kiểm tra tình ...             ngày
# 6787  mở biểu đồ cột viettel solution ngày để xem bá...             ngày
# 6788  hãy mở biểu đồ cơ cấu viettel solution ngày để...             ngày
# 6789  mở dashboard viettel solution ngày để xem thôn...             ngày
#
#      thời gian (chi tiết)
# 0
# 1
# 2
# 3
# 4
# ...                   ...
# 6785
# 6786
# 6787
# 6788
# 6789
#
# [6790 rows x 3 columns]

# %%
need_dataset[need_dataset['câu lệnh sinh ra']=='']
# Out:
# Empty DataFrame
# Columns: [câu lệnh sinh ra, chu kỳ thời gian, thời gian (chi tiết)]
# Index: []

# %%
need_dataset = prompt_dataset[['câu lệnh sinh ra', 'chu kỳ thời gian']]
need_dataset.loc[:, 'thời gian (chi tiết)'] = [""]*len(need_dataset)

list_ngay = ['ngày hôm nay', 'ngày hôm qua', 'ngày hôm trước', 'hôm nay', 'hôm qua', 'sáng nay', 'trong ngày', 'hàng ngày', 'mỗi ngày', 'từng ngày', 'ngày mai', 'ngày này', 'ngày thứ năm tuần sau', 'ngày gần đây', 'ngày nay', 'suốt cả ngày', 'suốt ngày qua', 'ngày hiện tại', 'ngày hôm đó', 'theo lịch ngày', 'ngày kế tiếp', 'cuối ngày', 'ngày đầu tiên của tháng', 'ngày đầu tiên', 'ngày trước đó', 'ngày kia', 'hằng ngày', 'ngày nào đó', 'một ngày cụ thể', 'ngày sau', 'đầu ngày', 'ngày thứ ba', 'ngày thứ tư', 'ngày mới', 'ngày thứ hai', 'ngày']
dict_ngay = {
    
}
for key in list_ngay:
    for i in range(len(need_dataset)):
        if key in need_dataset.loc[i, 'câu lệnh sinh ra'] and need_dataset.loc[i, 'thời gian (chi tiết)'] =='' and need_dataset.loc[i, 'chu kỳ thời gian']=='ngày':
            need_dataset.loc[i, 'thời gian (chi tiết)'] = key
            
list_thang = ['trong tháng này', 'trong tháng', 'tháng này', 'mỗi tháng', 'hàng tháng', 'tháng trước', 'tháng hiện tại', 'tháng tới', 'cho tháng', 'tháng vừa qua', 'đầu tháng', 'suốt tháng', 'tháng vừa qua', 'theo tháng', 'suốt cả tháng', 'từ đầu tháng', 'vào cuối tháng', 'tháng sau', 'tháng tiếp theo', 'cả tháng', 'tháng qua', 'tháng mới', 'tháng đang diễn ra', 'tháng kế tiếp', 'ngày đầu tiên của tháng', 'tháng']
for key in list_thang:
    for i in range(len(need_dataset)):
        if key in need_dataset.loc[i, 'câu lệnh sinh ra'] and need_dataset.loc[i, 'thời gian (chi tiết)'] =='' and need_dataset.loc[i, 'chu kỳ thời gian']=='tháng':
            need_dataset.loc[i, 'thời gian (chi tiết)'] = key

for i in range(len(need_dataset)):
    if 'ngày' not in need_dataset.loc[i, 'câu lệnh sinh ra'] and 'tháng' not in need_dataset.loc[i, 'câu lệnh sinh ra'] and need_dataset.loc[i, 'thời gian (chi tiết)'] =='':
        need_dataset.loc[i, 'thời gian (chi tiết)'] = 'khác'

remain = need_dataset[need_dataset['thời gian (chi tiết)']!=""]
deleted = need_dataset[need_dataset['thời gian (chi tiết)']==""]

# %%
for i in deleted.index:
    print(deleted['chu kỳ thời gian'].loc[i], ':', deleted['câu lệnh sinh ra'].loc[i])
# Out:
# ngày : vào đầu tháng, lãnh đạo công ty cần mở db vtt để xem tổng quan mức độ tiến độ thực hiện các dự án
# ngày : lập kế hoạch mở đát bót chỉ huy đánh giá hiệu suất làm việc của nhân viên vĩnh phúc ngay trong tháng này
# tháng : làm ơn mở của công ty truyền thông viettel để có thể kiểm tra và cập nhật thông tin hàng ngày
# ngày : biểu đồ thị phần của ct tnhh viettel cho thấy doanh số bán hàng tăng mạnh trong tháng này
# ngày : hãy mở để kiểm tra số liệu vbd tháng trước
# tháng : biểu đồ cơ cấu của công ty tnhh nn mtv tm&xnk vcm được cập nhật hằng ngày để quản lý chất lượng sản phẩm
# tháng : dashboard của công ty tnhh nn mtv tm&xnk vcm được cập nhật hằng ngày để quản lý chất lượng sản phẩm
# tháng : db chỉ huy của công ty tnhh nn mtv tm&xnk vcm được cập nhật hằng ngày để quản lý chất lượng sản phẩm
# tháng : biểu đồ rank của công ty tnhh nn mtv tm&xnk vcm được cập nhật hằng ngày để quản lý chất lượng sản phẩm
# tháng : dashboard của trung tâm thể thao viettel giúp các vận động viên có thể quản lý và kiểm soát tốt hơn việc tập luyện hàng ngày
# ngày : để biết thêm thông tin về chỉ tiêu doanh thu của phú yên trong tháng này, hãy mở dashboard để xem chi tiết
# ngày : bạn có thể mở tổng quan hoạt động kinh doanh của natcom nat trong tháng này không
# tháng : để đảm bảo hoạt động hiệu quả, công ty burundi vbd cần mở hàng ngày để xem kết quả làm việc
# tháng : thành viên trong công ty burundi vbd đã được hướng dẫn cách mở đát bót để theo dõi và đánh giá tiến độ làm việc hàng ngày
# tháng : việc mở đát bót chỉ huy hàng ngày của viettel tổng công ty viễn thông vtt giúp cán bộ quản lý nắm bắt thông tin và đưa ra quyết định nhanh chóng
# tháng : mở biểu đồ cảnh báo 2 viettel ninh bình, bạn sẽ tìm thấy thông tin cần thiết về cuộc sống hàng ngày
# tháng : tôi nhớ mở dashboard của viettel hpg hàng ngày để cập nhật thông tin mới nhất
# tháng : mỗi ngày, tôi đều mở đát bọt chỉ huy viettel bte để cập nhật thông tin mới nhất
# tháng : trong quý này, tôi đã mở biểu đồ cảnh báo 2 viettel stl hàng ngày để theo dõi tiến độ dự án
# tháng : hãy mở biểu đồ cảnh báo 2 viettel trung tâm thể thao viettel trong vòng 30 ngày

# %%
def sorted_by_key(diction):
    key_sorted = [(len(key), key) for key in diction.keys()]
    key_sorted = sorted(key_sorted, reverse=True)
    diction = {j:diction[j] for i, j in key_sorted}
    return diction

# %%
dict_ngay = {
    'ngày đầu tiên của tháng': "ngày đầu tháng này", 
    'theo lịch ngày': "khác", 
    'mỗi ngày': "khác", 
    'trong ngày': "khác", 
    'sáng nay': "hôm nay", 
    'ngày nào đó': "khác", 
    'ngày kia': "ngày kia", 
    'hằng ngày': "khác", 
    'suốt ngày qua': "khác", 
    'ngày thứ năm tuần sau': "thứ năm tuần sau", 
    'ngày sau': "ngày mai", 
    'ngày thứ hai': "thứ hai tuần gần nhất", 
    'đầu ngày': "khác", 
    'hôm nay': "hôm nay", 
    'ngày trước đó': "hôm qua", 
    'ngày mai': 'ngày mai', 
    'ngày này': 'hôm nay', 
    'ngày thứ tư': "thứ tư tuần gần nhất", 
    'ngày hôm qua': "hôm qua", 
    'ngày hôm nay': "hôm nay", 
    'ngày thứ ba': "thứ ba tuần gần nhất", 
    'ngày gần đây': "hôm qua", 
    'ngày hôm trước': "hôm qua", 
    'ngày đầu tiên': "khác", 
    'một ngày cụ thể': "khác", 
    'ngày hôm đó': "khác", 
    'từng ngày': "khác", 
    'ngày mới': "khác", 
    'ngày': "khác", 
    'ngày hiện tại': "hôm nay", 
    'suốt cả ngày': "khác", 
    'hàng ngày': "khác", 
    'cuối ngày': "khác", 
    'hôm qua': "hôm qua", 
    'ngày kế tiếp': "ngày mai", 
    'ngày nay': "hôm nay"
}

dict_thang = {
    'tháng kế tiếp': 'tháng sau', 
    'ngày đầu tiên của tháng': 'ngày đầu tháng này', 
    'tháng mới': 'tháng sau', 
    'tháng sau': 'tháng sau', 
    'tháng hiện tại': 'tháng này', 
    'theo tháng': 'khác', 
    'đầu tháng': 'ngày đầu tháng này', 
    'tháng này': 'tháng này', 
    'tháng trước': 'tháng trước', 
    'tháng tới': 'tháng sau', 
    'tháng vừa qua': 'tháng sau', 
    'từ đầu tháng': 'ngày đầu tháng này', 
    'mỗi tháng': 'khác', 
    'tháng đang diễn ra': 'tháng này', 
    'vào cuối tháng': 'ngày cuối tháng này', 
    'hàng tháng': 'khác', 
    'suốt tháng': 'khác', 
    'tháng': 'khác', 
    'cho tháng': 'khác', 
    'cả tháng': 'khác', 
    'tháng tiếp theo': 'tháng sau', 
    'tháng qua': 'tháng trước', 
    'trong tháng này': 'khác', 
    'trong tháng': 'khác', 
    'suốt cả tháng': 'khác'
}



dict_all = {**dict_ngay, **dict_thang, **{"khác": 'khác'}}
dict_all = sorted_by_key(dict_all)

# %%
list(set(dict_all.values()))
# Out:
# ['ngày cuối tháng này',
#  'thứ tư tuần gần nhất',
#  'tháng này',
#  'tháng sau',
#  'ngày mai',
#  'ngày đầu tháng này',
#  'thứ hai tuần gần nhất',
#  'ngày kia',
#  'tháng trước',
#  'thứ ba tuần gần nhất',
#  'hôm nay',
#  'hôm qua',
#  'thứ năm tuần sau',
#  'khác']

# %%
time2dictnonum = {
    # ngày theo tuần
    'thứ 2': {'thứ': '2', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 3': {'thứ': '3', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 4': {'thứ': '4', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 5': {'thứ': '5', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 6': {'thứ': '6', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ 7': {'thứ': '7', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},

    'thứ hai': {'thứ': '2', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba': {'thứ': '3', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư': {'thứ': '4', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm': {'thứ': '5', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu': {'thứ': '6', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy': {'thứ': '7', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},

    # ngày so với hôm nay
    'hôm kia': {'thứ': '', 'ngày': 'hôm kia', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'hôm qua': {'thứ': '', 'ngày': 'hôm qua', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'hôm nay': {'thứ': '', 'ngày': 'hôm nay', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'ngày mai': {'thứ': '', 'ngày': 'mai', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},
    'ngày kia': {'thứ': '', 'ngày': 'kia', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},

    # ngày theo tuần so với tuần này
    'thứ hai tuần sau': {'thứ': '2', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba tuần sau': {'thứ': '3', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư tuần sau': {'thứ': '4', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm tuần sau': {'thứ': '5', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu tuần sau': {'thứ': '6', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy tuần sau': {'thứ': '7', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật tuần sau': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},

    'thứ hai tuần này': {'thứ': '2', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba tuần này': {'thứ': '3', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư tuần này': {'thứ': '4', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm tuần này': {'thứ': '5', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu tuần này': {'thứ': '6', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy tuần này': {'thứ': '7', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật tuần này': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},

    'thứ hai tuần trước': {'thứ': '2', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba tuần trước': {'thứ': '3', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư tuần trước': {'thứ': '4', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm tuần trước': {'thứ': '5', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu tuần trước': {'thứ': '6', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy tuần trước': {'thứ': '7', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật tuần trước': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    
    'thứ hai tuần gần nhất': {'thứ': '2', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ ba tuần gần nhất': {'thứ': '3', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ tư tuần gần nhất': {'thứ': '4', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ năm tuần gần nhất': {'thứ': '5', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ sáu tuần gần nhất': {'thứ': '6', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'thứ bảy tuần gần nhất': {'thứ': '7', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},
    'chủ nhật tuần gần nhất': {'thứ': 'chủ nhật', 'ngày': '', 'tuần': 'gần nhất', 'tháng': '', 'quý': '', 'năm': ''},

    # ngày theo tháng so với tháng hiện tại
    'ngày đầu tháng này': {'thứ': '', 'ngày': 'đầu', 'tuần': '', 'tháng': 'này', 'quý': '', 'năm': ''},
    'ngày cuối tháng này': {'thứ': '', 'ngày': 'cuối', 'tuần': '', 'tháng': 'này', 'quý': '', 'năm': ''},
    'ngày đầu tháng sau': {'thứ': '', 'ngày': 'đầu', 'tuần': '', 'tháng': 'sau', 'quý': '', 'năm': ''},
    'ngày cuối tháng sau': {'thứ': '', 'ngày': 'cuối', 'tuần': '', 'tháng': 'sau', 'quý': '', 'năm': ''},
    'ngày đầu tháng trước': {'thứ': '', 'ngày': 'đầu', 'tuần': '', 'tháng': 'trước', 'quý': '', 'năm': ''},
    'ngày cuối tháng trước': {'thứ': '', 'ngày': 'cuối', 'tuần': '', 'tháng': 'trước', 'quý': '', 'năm': ''},

    # tuần so với tuần hiện tại
    'tuần trước': {'thứ': '', 'ngày': '', 'tuần': 'trước', 'tháng': '', 'quý': '', 'năm': ''},
    'tuần này': {'thứ': '', 'ngày': '', 'tuần': 'này', 'tháng': '', 'quý': '', 'năm': ''},
    'tuần sau': {'thứ': '', 'ngày': '', 'tuần': 'sau', 'tháng': '', 'quý': '', 'năm': ''},


    # tháng so với tháng hiện tại
    'tháng trước': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'trước', 'quý': '', 'năm': ''},
    'tháng này': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'này', 'quý': '', 'năm': ''},
    'tháng sau': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'sau', 'quý': '', 'năm': ''},
}


time2dictwithnum = {
    ## ngày
    # xxx/yyy/zzz
    'ngày xxx tháng yyy năm zzz': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    'xxx/yyy/zzz': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    'zzz/yyy/xxx': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    
    # xxx/yyy
    'ngày xxx tháng yyy': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': ''},
    'xxx/yyy': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': ''},

    # xxx
    'ngày xxx': {'thứ': '', 'ngày': 'xxx', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''},

    ## tháng
    # xxx/zzz
    'tháng yyy năm zzz':  {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    'yyy/zzz': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},
    'zzz/yyy': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': 'zzz'},

    # yyy
    'tháng yyy':  {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': 'yyy', 'quý': '', 'năm': ''},

    ## quý
    # ttt/zzz
    'quý ttt năm zzz': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': 'ttt', 'năm': 'zzz'},

    # ttt
    'quý ttt': {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': 'ttt', 'năm': ''},

    ## năm
    # zzz
    'năm zzz':  {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': 'zzz'},
}

time2dict = {**time2dictnonum, **time2dictwithnum, **{"khác": {'thứ': '', 'ngày': '', 'tuần': '', 'tháng': '', 'quý': '', 'năm': ''}}}
time2dict = sorted_by_key(time2dict)

# %%
time2dictngay = {u: v for u, v in time2dict.items() if ('hôm' in u or 'ngày' in u or 'thứ' in u or 'tuần' in u or 'xxx' in u)}
time2dictthang = {u: v for u, v in time2dict.items() if (u not in time2dictngay.keys())}

# %%
remain = need_dataset[need_dataset['thời gian (chi tiết)']!=""]
remain['thời gian'] = remain['thời gian (chi tiết)'].apply(lambda x: dict_all[x])
remain['thời gian (mới)'] = remain['thời gian'].apply(lambda x: x if x != 'khác' else "")
index_replace_ngay = remain.index[(remain['thời gian (mới)']=='') & (remain['chu kỳ thời gian']=='ngày')]
remain['thời gian (mới)'].loc[index_replace_ngay] = [random.choice(list(time2dictngay.keys())) for _ in range(len(index_replace_ngay))]
index_replace_thang = remain.index[(remain['thời gian (mới)']=='') & (remain['chu kỳ thời gian']=='tháng')]
remain['thời gian (mới)'].loc[index_replace_thang] = [random.choice(list(time2dictthang.keys())) for _ in range(len(index_replace_thang))]

remain['thời gian (dict)'] = remain['thời gian (mới)'].apply(lambda x: time2dict[x])
for key in remain['thời gian (dict)'].loc[0]:
    remain[key] = remain['thời gian (dict)'].apply(lambda x: x[key] if x[key] != '' else 'khác')

# remain['thời gian (chi tiết)()']
remain['ngày'] = remain['ngày'].apply(lambda x: str(random.choice(list(range(1, 32)))) if x=='xxx' else x)
remain['tháng'] = remain['tháng'].apply(lambda x: str(random.choice(list(range(1, 13)))) if x=='yyy' else x)
remain['năm'] = remain['năm'].apply(lambda x: str(random.choice(list(range(32, 10000)))) if x=='zzz' else x)
remain['quý'] = remain['quý'].apply(lambda x: str(random.choice(list(range(1, 5))+['I', 'II', 'III', 'IV'])) if x=='ttt' else x)
def feature2dict(diction, thu, ngay, tuan, thang, quy, nam):
    diction['thứ']=thu
    diction['ngày']=ngay
    diction['tuần']=tuan
    diction['tháng']=thang
    diction['quý']=quy
    diction['năm']=nam
    return diction

remain['thời gian (dict)'] = remain[['thời gian (dict)', 'thứ', 'ngày', 'tuần', 'tháng', 'quý', 'năm']].apply(lambda x: feature2dict(x['thời gian (dict)'], x['thứ'], x['ngày'], x['tuần'], x['tháng'], x['quý'], x['năm']), axis=1)
remain['câu lệnh sinh ra (mới)'] = remain[['câu lệnh sinh ra', 'thời gian (chi tiết)', 'thời gian (mới)']].apply(lambda x: x['câu lệnh sinh ra'].replace(x['thời gian (chi tiết)'], x['thời gian (mới)']), axis=1)
remain
# Out:
#                                        câu lệnh sinh ra chu kỳ thời gian  \
# 0     hãy mở biểu đồ cơ cấu của tập đoàn trong ngày ...             ngày
# 1     trưởng phòng đã ra lệnh mở biểu đồ kết hợp đườ...             ngày
# 2     sáng nay, chúng ta sẽ mở đát bót chỉ huy của t...             ngày
# 3     truy cập biểu đồ cảnh báo 2 tập đoàn trong ngà...             ngày
# 4     quản lý yêu cầu mở cho tất cả nhân viên tập đo...             ngày
# ...                                                 ...              ...
# 6785  mở đát bọt việt solution ngày để truy cập các ...             ngày
# 6786  hãy mở viettel solution ngày để kiểm tra tình ...             ngày
# 6787  mở biểu đồ cột viettel solution ngày để xem bá...             ngày
# 6788  hãy mở biểu đồ cơ cấu viettel solution ngày để...             ngày
# 6789  mở dashboard viettel solution ngày để xem thôn...             ngày
#
#      thời gian (chi tiết) thời gian        thời gian (mới)  \
# 0            ngày hôm nay   hôm nay                hôm nay
# 1                 hôm nay   hôm nay                hôm nay
# 2                sáng nay   hôm nay                hôm nay
# 3              trong ngày      khác       thứ bảy tuần này
# 4                 hôm nay   hôm nay                hôm nay
# ...                   ...       ...                    ...
# 6785                 ngày      khác                 thứ tư
# 6786                 ngày      khác     ngày đầu tháng sau
# 6787                 ngày      khác  ngày cuối tháng trước
# 6788                 ngày      khác                hôm nay
# 6789            hàng ngày      khác  ngày cuối tháng trước
#
#                                        thời gian (dict)   thứ     ngày  tuần  \
# 0     {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...  khác  hôm nay  khác
# 1     {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...  khác  hôm nay  khác
# 2     {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...  khác  hôm nay  khác
# 3     {'thứ': '7', 'ngày': 'khác', 'tuần': 'này', 't...     7     khác   này
# 4     {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...  khác  hôm nay  khác
# ...                                                 ...   ...      ...   ...
# 6785  {'thứ': '4', 'ngày': 'khác', 'tuần': 'khác', '...     4     khác  khác
# 6786  {'thứ': 'khác', 'ngày': 'đầu', 'tuần': 'khác',...  khác      đầu  khác
# 6787  {'thứ': 'khác', 'ngày': 'cuối', 'tuần': 'khác'...  khác     cuối  khác
# 6788  {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...  khác  hôm nay  khác
# 6789  {'thứ': 'khác', 'ngày': 'cuối', 'tuần': 'khác'...  khác     cuối  khác
#
#       tháng   quý   năm                             câu lệnh sinh ra (mới)
# 0      khác  khác  khác   hãy mở biểu đồ cơ cấu của tập đoàn trong hôm nay
# 1      khác  khác  khác  trưởng phòng đã ra lệnh mở biểu đồ kết hợp đườ...
# 2      khác  khác  khác  hôm nay, chúng ta sẽ mở đát bót chỉ huy của tậ...
# 3      khác  khác  khác  truy cập biểu đồ cảnh báo 2 tập đoàn thứ bảy t...
# 4      khác  khác  khác  quản lý yêu cầu mở cho tất cả nhân viên tập đo...
# ...     ...   ...   ...                                                ...
# 6785   khác  khác  khác  mở đát bọt việt solution thứ tư để truy cập cá...
# 6786    sau  khác  khác  hãy mở viettel solution ngày đầu tháng sau để ...
# 6787  trước  khác  khác  mở biểu đồ cột viettel solution ngày cuối thán...
# 6788   khác  khác  khác  hãy mở biểu đồ cơ cấu viettel solution hôm nay...
# 6789  trước  khác  khác  mở dashboard viettel solution ngày để xem thôn...
#
# [6770 rows x 13 columns]

# %%
necessary_remain = remain[['câu lệnh sinh ra (mới)', 'thời gian (dict)']]
necessary_remain
# Out:
#                                  câu lệnh sinh ra (mới)  \
# 0      hãy mở biểu đồ cơ cấu của tập đoàn trong hôm nay
# 1     trưởng phòng đã ra lệnh mở biểu đồ kết hợp đườ...
# 2     hôm nay, chúng ta sẽ mở đát bót chỉ huy của tậ...
# 3     truy cập biểu đồ cảnh báo 2 tập đoàn thứ bảy t...
# 4     quản lý yêu cầu mở cho tất cả nhân viên tập đo...
# ...                                                 ...
# 6785  mở đát bọt việt solution thứ tư để truy cập cá...
# 6786  hãy mở viettel solution ngày đầu tháng sau để ...
# 6787  mở biểu đồ cột viettel solution ngày cuối thán...
# 6788  hãy mở biểu đồ cơ cấu viettel solution hôm nay...
# 6789  mở dashboard viettel solution ngày để xem thôn...
#
#                                        thời gian (dict)
# 0     {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...
# 1     {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...
# 2     {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...
# 3     {'thứ': '7', 'ngày': 'khác', 'tuần': 'này', 't...
# 4     {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...
# ...                                                 ...
# 6785  {'thứ': '4', 'ngày': 'khác', 'tuần': 'khác', '...
# 6786  {'thứ': 'khác', 'ngày': 'đầu', 'tuần': 'khác',...
# 6787  {'thứ': 'khác', 'ngày': 'cuối', 'tuần': 'khác'...
# 6788  {'thứ': 'khác', 'ngày': 'hôm nay', 'tuần': 'kh...
# 6789  {'thứ': 'khác', 'ngày': 'cuối', 'tuần': 'khác'...
#
# [6770 rows x 2 columns]

# %%
necessary_remain['câu lệnh sinh ra (mới)'].tolist()[:30]
# Out:
# ['hãy mở biểu đồ cơ cấu của tập đoàn trong hôm nay',
#  'trưởng phòng đã ra lệnh mở biểu đồ kết hợp đường và cột cho toàn tập đoàn vào hôm nay',
#  'hôm nay, chúng ta sẽ mở đát bót chỉ huy của tập đoàn để xem thông tin mới nhất',
#  'truy cập biểu đồ cảnh báo 2 tập đoàn thứ bảy tuần này để cập nhật thông tin mới',
#  'quản lý yêu cầu mở cho tất cả nhân viên tập đoàn hôm nay',
#  'tôi đã mở biểu đồ của vtc tháng trước',
#  'bạn hãy mở biểu đồ cơ cấu để kiểm tra dữ liệu chủ nhật',
#  'tháng này, vtc cần tôi mở biểu đồ rank để cập nhật danh sách khách hàng',
#  'khác, tôi phải mở biểu đồ của vtc để xem báo cáo',
#  'để tiện theo dõi, tôi đã tạo tiện ích mở biểu đồ cột từ vtc tháng trước',
#  'hãy mở thống kê của công ty mẹ cho tháng này',
#  'mở db để xem báo cáo tài chính yyy/zzz của công ty mẹ',
#  'hãy mở để theo dõi tiến độ dự án của công ty mẹ tháng này',
#  'vui lòng mở dashboard công việc chung của toàn bộ công ty mẹ quý ttt năm zzz',
#  'hãy mở biểu đồ rank nhân sự của công ty mẹ để kiểm tra thông tin nhân viên zzz/yyy',
#  'mở dashboard vtc để kiểm tra chỉ số hôm nay',
#  'hãy mở đát bọt chỉ huy vtc để xem thông tin cập nhật thứ sáu',
#  'mở vtc để kiểm tra chỉ số ngày đầu tháng sau của các hoạt động',
#  'bạn hãy mở biểu đồ cảnh báo 2 vtc để theo dõi thông tin của hôm nay',
#  'hãy mở vtc để theo dõi các số liệu và biểu đồ của thứ hai tuần sau',
#  'hôm nay, tôi mở để kiểm tra nat thường xuyên',
#  'nat đã được mở trên dashboard từ sáng đến chiều nay',
#  'biểu đồ rank hiển thị thông tin nat thứ ba tuần sau của tôi',
#  'tôi nhớ mở đát bọt chỉ huy để kiểm tra nat thứ 6',
#  'các thông số nat hôm qua đã được ghi nhận trên đát bọt',
#  'tôi muốn mở để kiểm tra mov của tháng trước',
#  'tháng này, tôi đang sử dụng mov để đánh giá hiệu suất công việc trên biểu đồ đường của tôi',
#  'để nắm bắt tình hình hoạt động, tôi thường mở biểu đồ để xem tiến độ công việc của các thành viên tháng yyy',
#  ' hiển thị rõ ràng các chỉ số mov chủ nhật, giúp tôi theo dõi và đánh giá kết quả làm việc',
#  'mỗi ngày, khi bắt đầu làm việc, tôi thường mở đát bọt chỉ huy để xem tỷ lệ hoàn thành công việc chủ nhật và điều chỉnh kế hoạch']

# %%
necessary_remain['thời gian (dict)'].tolist()[:30]
# Out:
# [{'thứ': 'khác',
#   'ngày': 'hôm nay',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'hôm nay',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'hôm nay',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': '7',
#   'ngày': 'khác',
#   'tuần': 'này',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'hôm nay',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'trước',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'chủ nhật',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'này',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'trước',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'này',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': '3',
#   'quý': 'khác',
#   'năm': '6460'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'này',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'I',
#   'năm': '2245'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': '9',
#   'quý': 'khác',
#   'năm': '4880'},
#  {'thứ': 'khác',
#   'ngày': 'hôm nay',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': '6',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'đầu',
#   'tuần': 'khác',
#   'tháng': 'sau',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'hôm nay',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': '2',
#   'ngày': 'khác',
#   'tuần': 'sau',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'hôm nay',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': '2',
#   'ngày': 'khác',
#   'tuần': 'sau',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': '3',
#   'ngày': 'khác',
#   'tuần': 'sau',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': '6',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'hôm qua',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'trước',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'này',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'khác',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': '11',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'chủ nhật',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'},
#  {'thứ': 'chủ nhật',
#   'ngày': 'khác',
#   'tuần': 'khác',
#   'tháng': 'khác',
#   'quý': 'khác',
#   'năm': 'khác'}]

# %% [markdown]
# # Current date

# %%
from datetime import date

today = date.today()
today
# Out:
# datetime.date(2023, 8, 25)

# %%
someday = date(2023, 8, 21)
someday.weekday()
# Out:
# 0

# %%
def get_current_date():
    # Denote: 2 is Monday, 8 is Sunday
    from datetime import date
    today = date.today()
    return (today.year, today.month, today.day, today.weekday()+2)


get_current_date()
# Out:
# (2023, 8, 25, 6)

# %%
a = today.weekday()
a
# Out:
# 4

# %%
remain['thời gian'] = remain['thời gian (chi tiết)'].apply(lambda x: dict_all[x])

# %%
remain['thời gian'].value_counts()
# Out:
# khác                     4150
# hôm nay                  1153
# tháng này                 723
# hôm qua                   238
# ngày mai                  220
# tháng trước               126
# tháng sau                  72
# ngày đầu tháng này         56
# ngày cuối tháng này        18
# ngày kia                    5
# thứ hai tuần gần nhất       4
# thứ ba tuần gần nhất        3
# thứ tư tuần gần nhất        1
# thứ năm tuần sau            1
# Name: thời gian, dtype: int64

# %%
remain['thời gian (chi tiết)'].value_counts()[25:50]
# Out:
# tháng vừa qua              17
# ngày hôm trước             15
# ngày mới                   15
# tháng tới                  13
# ngày kế tiếp               12
# ngày đầu tiên              12
# ngày nay                   12
# hôm qua                    12
# đầu ngày                   11
# cuối ngày                  10
# tháng qua                  10
# hằng ngày                  10
# tháng mới                   7
# theo tháng                  6
# từng ngày                   6
# suốt cả tháng               6
# ngày hôm đó                 5
# ngày kia                    5
# ngày gần đây                4
# ngày thứ hai                4
# ngày thứ ba                 3
# ngày trước đó               3
# ngày đầu tiên của tháng     3
# một ngày cụ thể             2
# ngày sau                    2
# Name: thời gian (chi tiết), dtype: int64

# %%
remain['thời gian (chi tiết)'].value_counts()[50:75]
# Out:
# cả tháng                 2
# tháng đang diễn ra       2
# tháng tiếp theo          2
# suốt cả ngày             2
# theo lịch ngày           1
# suốt ngày qua            1
# ngày thứ tư              1
# ngày nào đó              1
# tháng kế tiếp            1
# ngày thứ năm tuần sau    1
# Name: thời gian (chi tiết), dtype: int64
