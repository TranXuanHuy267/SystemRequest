# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers wandb datasets sentencepiece
# Out:
# Collecting transformers
#   Downloading transformers-4.32.1-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 22.9 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.15.9-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 53.3 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.14.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 54.1 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 64.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 34.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 90.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 81.5 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 23.3 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.30.0-py2.py3-none-any.whl (218 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.8/218.8 kB 27.8 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.7 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=1896dfe36522c5beff660d7153a00c05f618a75794bd86107745cbfcbd688a21
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: tokenizers, sentencepiece, safetensors, pathtools, xxhash, smmap, setproctitle, sentry-sdk, docker-pycreds, dill, multiprocess, huggingface-hub, gitdb, transformers, GitPython, wandb, datasets
# Successfully installed GitPython-3.1.32 datasets-2.14.4 dill-0.3.7 docker-pycreds-0.4.0 gitdb-4.0.10 huggingface-hub-0.16.4 multiprocess-0.70.15 pathtools-0.1.2 safetensors-0.3.3 sentencepiece-0.1.99 sentry-sdk-1.30.0 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.3 transformers-4.32.1 wandb-0.15.9 xxhash-3.3.0

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("/content/drive/MyDrive")

# %%
import os
os.chdir("/content/drive/MyDrive/SystemRequest/Achatbot")

# %%
# !python text2table/train2.py --model_name vinai/bartpho-syllable-base --batch_size 1 --epochs 20
# Out:
# 2023-08-30 07:02:29.271779: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Namespace(train_sample_path='./data/dashboard/train_samples.jsonl', train_description_path='./data/dashboard/train_descriptions.txt', val_sample_path='./data/dashboard/val_samples.jsonl', val_description_path='./data/dashboard/val_descriptions.txt', test_sample_path='./data/dashboard/test_samples.jsonl', test_description_path='./data/dashboard/test_descriptions.txt', model_name='vinai/bartpho-syllable-base', max_source_length=256, max_target_length=256, epochs=20, batch_size=1, learning_rate=3e-05, device='cuda', metric='BLEU', beam_size=5, load_model_path=None, output_dir='./output', wandb_project=None, debug=False, gradient_accumulation_steps=1, max_grad_norm=0, warmup_steps=0, seed=42, skip_test_loss=False)
# ####################################################################################################
#
# Loading tokenizer vinai/bartpho-syllable-base
# Downloading (…)lve/main/config.json: 100% 898/898 [00:00<00:00, 5.10MB/s]
# Downloading (…)tencepiece.bpe.model: 100% 5.07M/5.07M [00:00<00:00, 82.5MB/s]
# Downloading (…)esolve/main/dict.txt: 100% 360k/360k [00:00<00:00, 2.00MB/s]
# Using model vinai/bartpho-syllable-base
# Downloading pytorch_model.bin: 100% 526M/526M [00:03<00:00, 146MB/s]
# Number of parameters: 131,563,008
# Epoch: 0
# Epoch: 0, Train Loss: 0.0066, Avg Train Loss: 0.0572: 100% 4540/4540 [06:58<00:00, 10.85it/s]
# Epoch: 0, Avg Train Loss: 0.0572
# Epoch: 0, Eval Loss: 0.0001, Avg Eval Loss: 0.0120: 100% 568/568 [00:11<00:00, 51.39it/s]
# Epoch: 0, Avg Val Loss: 0.0120
# Best loss model saved to ./output/vinai/bartpho-syllable-base
# Epoch: 0, BLEU: 1.0000, Avg BLEU: 0.9631: 100% 568/568 [09:12<00:00,  1.03it/s]
# Input: hãy mở biểu đồ rank của viettel high tech tháng sau
# Output: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
# Target: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
#
# Number of instances:  568
# Number of correct format instances: 568
# The macro recall of  LOẠI BIỂU ĐỒ : 0.996368122378485
# The macro recall of  ĐƠN VỊ : 0.8741783126293996
# The macro recall of  CHU KỲ THỜI GIAN : 0.9251158186483487
# The macro recall of  THỨ : 0.8062907859270818
# The macro recall of  NGÀY : 0.6850768043653668
# The macro recall of  TUẦN : 0.7639766081871345
# The macro recall of  THÁNG : 0.9717094806534462
# The macro recall of  QUÝ : 0.9775689223057644
# The macro recall of  NĂM : 0.9567307692307693
# Epoch: 0, Avg BLEU: 0.9631
# Best BLEU model saved to ./output/vinai/bartpho-syllable-base
# End of Epoch: 0
# Avg Train Loss: 0.0572
# Avg Val Loss: 0.0120
# Avg Val BLEU: 0.9631
# ##################################################
#
# Epoch: 1
# Epoch: 1, Train Loss: 0.0012, Avg Train Loss: 0.0111: 100% 4540/4540 [06:52<00:00, 11.02it/s]
# Epoch: 1, Avg Train Loss: 0.0111
# Epoch: 1, Eval Loss: 0.0634, Avg Eval Loss: 0.0092: 100% 568/568 [00:12<00:00, 46.81it/s]
# Epoch: 1, Avg Val Loss: 0.0092
# Best loss model saved to ./output/vinai/bartpho-syllable-base
# Epoch: 1, BLEU: 0.8895, Avg BLEU: 0.9637: 100% 568/568 [09:08<00:00,  1.04it/s]
# Input: hãy mở biểu đồ rank của viettel high tech tháng sau
# Output: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vtl", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
# Target: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
#
# Number of instances:  568
# Number of correct format instances: 551
# The macro recall of  LOẠI BIỂU ĐỒ : 1.0
# The macro recall of  ĐƠN VỊ : 0.8961395790200138
# The macro recall of  CHU KỲ THỜI GIAN : 0.9344128776241678
# The macro recall of  THỨ : 0.7403445207220951
# The macro recall of  NGÀY : 0.7253445517397681
# The macro recall of  TUẦN : 0.8027369387656469
# The macro recall of  THÁNG : 0.9687080626657666
# The macro recall of  QUÝ : 0.9777777777777779
# The macro recall of  NĂM : 0.9567307692307693
# Epoch: 1, Avg BLEU: 0.9637
# Best BLEU model saved to ./output/vinai/bartpho-syllable-base
# End of Epoch: 1
# Avg Train Loss: 0.0111
# Avg Val Loss: 0.0092
# Avg Val BLEU: 0.9637
# ##################################################
#
# Epoch: 2
# Epoch: 2, Train Loss: 0.0001, Avg Train Loss: 0.0077: 100% 4540/4540 [06:56<00:00, 10.91it/s]
# Epoch: 2, Avg Train Loss: 0.0077
# Epoch: 2, Eval Loss: 0.0000, Avg Eval Loss: 0.0087: 100% 568/568 [00:11<00:00, 51.03it/s]
# Epoch: 2, Avg Val Loss: 0.0087
# Best loss model saved to ./output/vinai/bartpho-syllable-base
# Epoch: 2, BLEU: 1.0000, Avg BLEU: 0.9742: 100% 568/568 [09:04<00:00,  1.04it/s]
# Input: hãy mở biểu đồ rank của viettel high tech tháng sau
# Output: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
# Target: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
#
# Number of instances:  568
# Number of correct format instances: 566
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9944935404994321
# The macro recall of  ĐƠN VỊ : 0.9543107315389924
# The macro recall of  CHU KỲ THỜI GIAN : 0.937871211682076
# The macro recall of  THỨ : 0.821171187773355
# The macro recall of  NGÀY : 0.7244264235571117
# The macro recall of  TUẦN : 0.8054863826232248
# The macro recall of  THÁNG : 0.9606379731379732
# The macro recall of  QUÝ : 0.9777777777777779
# The macro recall of  NĂM : 0.9567307692307693
# Epoch: 2, Avg BLEU: 0.9742
# Best BLEU model saved to ./output/vinai/bartpho-syllable-base
# End of Epoch: 2
# Avg Train Loss: 0.0077
# Avg Val Loss: 0.0087
# Avg Val BLEU: 0.9742
# ##################################################
#
# Epoch: 3
# Epoch: 3, Train Loss: 0.0000, Avg Train Loss: 0.0060: 100% 4540/4540 [06:54<00:00, 10.96it/s]
# Epoch: 3, Avg Train Loss: 0.0060
# Epoch: 3, Eval Loss: 0.0001, Avg Eval Loss: 0.0055: 100% 568/568 [00:10<00:00, 55.38it/s]
# Epoch: 3, Avg Val Loss: 0.0055
# Best loss model saved to ./output/vinai/bartpho-syllable-base
# Epoch: 3, BLEU: 1.0000, Avg BLEU: 0.9515: 100% 568/568 [09:00<00:00,  1.05it/s]
# Input: hãy mở biểu đồ rank của viettel high tech tháng sau
# Output: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
# Target: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
#
# Number of instances:  568
# Number of correct format instances: 568
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9930915371329879
# The macro recall of  ĐƠN VỊ : 0.9634963768115942
# The macro recall of  CHU KỲ THỜI GIAN : 0.8917007182841724
# The macro recall of  THỨ : 0.8126076787881653
# The macro recall of  NGÀY : 0.8025216515943514
# The macro recall of  TUẦN : 0.7904296669818259
# The macro recall of  THÁNG : 0.97961901604143
# The macro recall of  QUÝ : 0.9777777777777779
# The macro recall of  NĂM : 0.9567307692307693
# Epoch: 3, Avg BLEU: 0.9515
# End of Epoch: 3
# Avg Train Loss: 0.0060
# Avg Val Loss: 0.0055
# Avg Val BLEU: 0.9515
# ##################################################
#
# Epoch: 4
# Epoch: 4, Train Loss: 0.0001, Avg Train Loss: 0.0049: 100% 4540/4540 [06:52<00:00, 11.02it/s]
# Epoch: 4, Avg Train Loss: 0.0049
# Epoch: 4, Eval Loss: 0.0000, Avg Eval Loss: 0.0054: 100% 568/568 [00:11<00:00, 51.37it/s]
# Epoch: 4, Avg Val Loss: 0.0054
# Best loss model saved to ./output/vinai/bartpho-syllable-base
# Epoch: 4, BLEU: 1.0000, Avg BLEU: 0.9789: 100% 568/568 [09:09<00:00,  1.03it/s]
# Input: hãy mở biểu đồ rank của viettel high tech tháng sau
# Output: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
# Target: "LOẠI BIỂU ĐỒ": "biểu đồ", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "sau", "QUÝ": "khác", "NĂM": "khác"
#
# Number of instances:  568
# Number of correct format instances: 568
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9983333333333334
# The macro recall of  ĐƠN VỊ : 0.9871980676328502
# The macro recall of  CHU KỲ THỜI GIAN : 0.8953342811692757
# The macro recall of  THỨ : 0.8450350522532747
# The macro recall of  NGÀY : 0.8551305238954965
# The macro recall of  TUẦN : 0.8033637987183526
# The macro recall of  THÁNG : 0.9835306934444866
# The macro recall of  QUÝ : 0.9777777777777779
# The macro recall of  NĂM : 0.9566888721300486
# Epoch: 4, Avg BLEU: 0.9789
# Best BLEU model saved to ./output/vinai/bartpho-syllable-base
# End of Epoch: 4
# Avg Train Loss: 0.0049
# Avg Val Loss: 0.0054
# Avg Val BLEU: 0.9789
# ##################################################
#
# Epoch: 5
# Epoch: 5, Train Loss: 0.0004, Avg Train Loss: 0.0037: 100% 4540/4540 [06:54<00:00, 10.96it/s]
# Epoch: 5, Avg Train Loss: 0.0037
# Epoch: 5, Eval Loss: 0.0000, Avg Eval Loss: 0.0069: 100% 568/568 [00:10<00:00, 56.09it/s]
# Epoch: 5, Avg Val Loss: 0.0069
# Epoch: 5, BLEU: 0.8467, Avg BLEU: 0.9740:  37% 208/568 [03:21<05:48,  1.03it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/SystemRequest/Achatbot/text2table/train2.py", line 109, in <module>
#     avg_val_score = get_scores(val_dataloader, model, tokenizer, Config, epoch)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/MyDrive/SystemRequest/Achatbot/text2table/utils.py", line 243, in get_scores
#     outputs = model.generate(
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py", line 1675, in generate
#     return self.beam_search(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py", line 3014, in beam_search
#     outputs = self(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/mbart/modeling_mbart.py", line 1357, in forward
#     outputs = self.model(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/mbart/modeling_mbart.py", line 1243, in forward
#     decoder_outputs = self.decoder(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/mbart/modeling_mbart.py", line 1108, in forward
#     layer_outputs = decoder_layer(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/mbart/modeling_mbart.py", line 443, in forward
#     hidden_states, cross_attn_weights, cross_attn_present_key_value = self.encoder_attn(
#   File "/usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py", line 1501, in _call_impl
#     return forward_call(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/mbart/modeling_mbart.py", line 228, in forward
#     query_states = self._shape(query_states, tgt_len, bsz).view(*proj_shape)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/models/mbart/modeling_mbart.py", line 168, in _shape
#     def _shape(self, tensor: torch.Tensor, seq_len: int, bsz: int):
# KeyboardInterrupt
# ^C

# %%
# !python text2table/train2.py --model_name facebook/mbart-large-50-many-to-many-mmt

# %%
# !git clone https://oauth2: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@github.com/TranXuanHuy267/SystemRequest.git

# %%
os.chdir("/content/drive/MyDrive/SystemRequest")

# %%
# !git config --global user.email "huysntq@gmail.com"
# !git config --global user.name "TranXuanHuy267"
# !git add .
# !git commit -m "eight commit"
# !git push https://oauth2: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@github.com/TranXuanHuy267/SystemRequest.git
# Out:
# [main e38ba64] eight commit
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite Achatbot/Text2TableTraining_2.ipynb (91%)
# Enumerating objects: 19, done.
# Counting objects: 100% (19/19), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (12/12), done.
# Writing objects: 100% (12/12), 4.10 KiB | 419.00 KiB/s, done.
# Total 12 (delta 5), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (5/5), completed with 4 local objects.
# To https://github.com/TranXuanHuy267/SystemRequest.git
#    df97e19..e38ba64  main -> main
