# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers wandb datasets sentencepiece
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 53.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 90.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 50.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 28.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 81.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.5/189.5 kB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.8/224.8 kB 13.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.4 MB/s eta 0:00:00
# ...

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("/content/drive/MyDrive")

# %%
import os
os.chdir("/content/drive/MyDrive/SystemRequest/Achatbot")

# %%
# !python text2table/train2.py --model_name vinai/bartpho-syllable-base --batch_size 1 --epochs 1
# Out:
# 2023-09-20 08:36:59.227779: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Namespace(train_sample_path='./data/table2text/train_samples.jsonl', train_description_path='./data/table2text/train_descriptions.txt', val_sample_path='./data/table2text/val_samples.jsonl', val_description_path='./data/table2text/val_descriptions.txt', test_sample_path='./data/table2text/test_samples.jsonl', test_description_path='./data/table2text/test_descriptions.txt', model_name='vinai/bartpho-syllable-base', max_source_length=256, max_target_length=512, epochs=1, batch_size=1, learning_rate=3e-05, device='cuda', metric='BLEU', beam_size=5, load_model_path=None, output_dir='./output', wandb_project=None, debug=False, gradient_accumulation_steps=1, max_grad_norm=0, warmup_steps=0, seed=42, skip_test_loss=False)
# ####################################################################################################
#
# ...

# %%
# !python text2table/train2.py --model_name facebook/mbart-large-50-many-to-many-mmt

# %%
# !git clone https://oauth2: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@github.com/TranXuanHuy267/SystemRequest.git

# %%
os.chdir("/content/drive/MyDrive/SystemRequest")

# %%
# !git config --global user.email "huysntq@gmail.com"
# !git config --global user.name "TranXuanHuy267"
# !git add .
# !git commit -m "text2table train all commit"
# !git push https://oauth2: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@github.com/TranXuanHuy267/SystemRequest.git
# Out:
# ^C
# On branch main
