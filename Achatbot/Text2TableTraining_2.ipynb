# %%
# !pip install transformers wandb datasets sentencepiece
# Out:
# Collecting transformers
#   Downloading transformers-4.32.1-py3-none-any.whl (7.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 22.8 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.15.9-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 47.4 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.14.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 42.3 MB/s eta 0:00:00
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.9 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.15.1 (from transformers)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 33.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 81.2 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.32-py3-none-any.whl (188 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 kB 26.4 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.29.2-py2.py3-none-any.whl (215 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 215.6/215.6 kB 29.5 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting pathtools (from wandb)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.2-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.9 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 11.3 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.8.5)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (3.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8791 sha256=7729b819cf8f38b53a36a3a2676bb4269d27e52ad55bc97355c5b5f88509d6d5
#   Stored in directory: /root/.cache/pip/wheels/e7/f3/22/152153d6eb222ee7a56ff8617d80ee5207207a8c00a7aab794
# Successfully built pathtools
# Installing collected packages: tokenizers, sentencepiece, safetensors, pathtools, xxhash, smmap, setproctitle, sentry-sdk, docker-pycreds, dill, multiprocess, huggingface-hub, gitdb, transformers, GitPython, wandb, datasets
# Successfully installed GitPython-3.1.32 datasets-2.14.4 dill-0.3.7 docker-pycreds-0.4.0 gitdb-4.0.10 huggingface-hub-0.16.4 multiprocess-0.70.15 pathtools-0.1.2 safetensors-0.3.3 sentencepiece-0.1.99 sentry-sdk-1.29.2 setproctitle-1.3.2 smmap-5.0.0 tokenizers-0.13.3 transformers-4.32.1 wandb-0.15.9 xxhash-3.3.0

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
os.chdir("/content/drive/MyDrive")

# %%
import os
os.chdir("/content/drive/MyDrive/SystemRequest/Achatbot")

# %%
# !python text2table/train2.py --model_name vinai/bartpho-syllable-base --batch_size 1 --epochs 20
# Out:
# 2023-08-29 07:35:18.408543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Namespace(train_sample_path='./data/dashboard/train_samples.jsonl', train_description_path='./data/dashboard/train_descriptions.txt', val_sample_path='./data/dashboard/val_samples.jsonl', val_description_path='./data/dashboard/val_descriptions.txt', test_sample_path='./data/dashboard/test_samples.jsonl', test_description_path='./data/dashboard/test_descriptions.txt', model_name='vinai/bartpho-syllable-base', max_source_length=256, max_target_length=256, epochs=20, batch_size=1, learning_rate=3e-05, device='cuda', metric='BLEU', beam_size=5, load_model_path=None, output_dir='./output', wandb_project=None, debug=False, gradient_accumulation_steps=1, max_grad_norm=0, warmup_steps=0, seed=42, skip_test_loss=False)
# ####################################################################################################
#
# Loading tokenizer vinai/bartpho-syllable-base
# Using model vinai/bartpho-syllable-base
# Number of parameters: 131,563,008
# Epoch: 0
# Epoch: 0, Train Loss: 0.0067, Avg Train Loss: 0.0552: 100% 4540/4540 [07:04<00:00, 10.69it/s]
# Epoch: 0, Avg Train Loss: 0.0552
# Epoch: 0, Eval Loss: 0.0058, Avg Eval Loss: 0.0098: 100% 568/568 [00:11<00:00, 48.56it/s]
# Epoch: 0, Avg Val Loss: 0.0098
# Best loss model saved to ./output/vinai/bartpho-syllable-base
# Epoch: 0, BLEU: 1.0000, Avg BLEU: 0.9665: 100% 568/568 [10:15<00:00,  1.08s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 567
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9907407407407408
# The macro recall of  ĐƠN VỊ : 0.9261149930986887
# The macro recall of  CHU KỲ THỜI GIAN : 0.9376555191954665
# The macro recall of  THỨ : 0.8552096596214243
# The macro recall of  NGÀY : 0.48598747529270175
# The macro recall of  TUẦN : 0.8325212803881457
# The macro recall of  THÁNG : 0.976436821177075
# The macro recall of  QUÝ : 0.861904761904762
# The macro recall of  NĂM : 0.9831521512766046
# Epoch: 0, Avg BLEU: 0.9665
# Best BLEU model saved to ./output/vinai/bartpho-syllable-base
# End of Epoch: 0
# Avg Train Loss: 0.0552
# Avg Val Loss: 0.0098
# Avg Val BLEU: 0.9665
# ##################################################
#
# Epoch: 1
# Epoch: 1, Train Loss: 0.0003, Avg Train Loss: 0.0102: 100% 4540/4540 [07:06<00:00, 10.66it/s]
# Epoch: 1, Avg Train Loss: 0.0102
# Epoch: 1, Eval Loss: 0.0012, Avg Eval Loss: 0.0066: 100% 568/568 [00:12<00:00, 46.53it/s]
# Epoch: 1, Avg Val Loss: 0.0066
# Best loss model saved to ./output/vinai/bartpho-syllable-base
# Epoch: 1, BLEU: 1.0000, Avg BLEU: 0.9707: 100% 568/568 [10:10<00:00,  1.07s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 568
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9964979831316465
# The macro recall of  ĐƠN VỊ : 0.9684735554300772
# The macro recall of  CHU KỲ THỜI GIAN : 0.916756181500503
# The macro recall of  THỨ : 0.8654314370116256
# The macro recall of  NGÀY : 0.6726641317314168
# The macro recall of  TUẦN : 0.7405581942922097
# The macro recall of  THÁNG : 0.9437314219689008
# The macro recall of  QUÝ : 0.861904761904762
# The macro recall of  NĂM : 0.9905244784307207
# Epoch: 1, Avg BLEU: 0.9707
# Best BLEU model saved to ./output/vinai/bartpho-syllable-base
# End of Epoch: 1
# Avg Train Loss: 0.0102
# Avg Val Loss: 0.0066
# Avg Val BLEU: 0.9707
# ##################################################
#
# Epoch: 2
# Epoch: 2, Train Loss: 0.0101, Avg Train Loss: 0.0073: 100% 4540/4540 [07:04<00:00, 10.69it/s]
# Epoch: 2, Avg Train Loss: 0.0073
# Epoch: 2, Eval Loss: 0.0001, Avg Eval Loss: 0.0056: 100% 568/568 [00:12<00:00, 46.39it/s]
# Epoch: 2, Avg Val Loss: 0.0056
# Best loss model saved to ./output/vinai/bartpho-syllable-base
# Epoch: 2, BLEU: 1.0000, Avg BLEU: 0.9769: 100% 568/568 [10:36<00:00,  1.12s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 567
# The macro recall of  LOẠI BIỂU ĐỒ : 1.0
# The macro recall of  ĐƠN VỊ : 0.9868659420289854
# The macro recall of  CHU KỲ THỜI GIAN : 0.9154038451703983
# The macro recall of  THỨ : 0.8369542324505559
# The macro recall of  NGÀY : 0.7139217595261518
# The macro recall of  TUẦN : 0.8333165090163763
# The macro recall of  THÁNG : 0.9818288515919564
# The macro recall of  QUÝ : 0.861904761904762
# The macro recall of  NĂM : 0.9779457703361241
# Epoch: 2, Avg BLEU: 0.9769
# Best BLEU model saved to ./output/vinai/bartpho-syllable-base
# End of Epoch: 2
# Avg Train Loss: 0.0073
# Avg Val Loss: 0.0056
# Avg Val BLEU: 0.9769
# ##################################################
#
# Epoch: 3
# Epoch: 3, Train Loss: 0.0011, Avg Train Loss: 0.0057: 100% 4540/4540 [07:03<00:00, 10.72it/s]
# Epoch: 3, Avg Train Loss: 0.0057
# Epoch: 3, Eval Loss: 0.0048, Avg Eval Loss: 0.0093: 100% 568/568 [00:10<00:00, 52.41it/s]
# Epoch: 3, Avg Val Loss: 0.0093
# Epoch: 3, BLEU: 1.0000, Avg BLEU: 0.9645: 100% 568/568 [10:09<00:00,  1.07s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 557
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9906367041198502
# The macro recall of  ĐƠN VỊ : 0.9339182194616977
# The macro recall of  CHU KỲ THỜI GIAN : 0.901072703058845
# The macro recall of  THỨ : 0.8580979456582998
# The macro recall of  NGÀY : 0.8321773241764681
# The macro recall of  TUẦN : 0.8563239948653123
# The macro recall of  THÁNG : 0.978858946367174
# The macro recall of  QUÝ : 0.8447971781305115
# The macro recall of  NĂM : 0.9999157681940701
# Epoch: 3, Avg BLEU: 0.9645
# End of Epoch: 3
# Avg Train Loss: 0.0057
# Avg Val Loss: 0.0093
# Avg Val BLEU: 0.9645
# ##################################################
#
# Epoch: 4
# Epoch: 4, Train Loss: 0.0000, Avg Train Loss: 0.0044: 100% 4540/4540 [07:01<00:00, 10.76it/s]
# Epoch: 4, Avg Train Loss: 0.0044
# Epoch: 4, Eval Loss: 0.0093, Avg Eval Loss: 0.0070: 100% 568/568 [00:11<00:00, 50.98it/s]
# Epoch: 4, Avg Val Loss: 0.0070
# Epoch: 4, BLEU: 1.0000, Avg BLEU: 0.9678: 100% 568/568 [10:00<00:00,  1.06s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 568
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9962962962962963
# The macro recall of  ĐƠN VỊ : 0.9875341144362884
# The macro recall of  CHU KỲ THỜI GIAN : 0.8508959954819012
# The macro recall of  THỨ : 0.8612579211930627
# The macro recall of  NGÀY : 0.7302312748385219
# The macro recall of  TUẦN : 0.8068093614257297
# The macro recall of  THÁNG : 0.9789644263548656
# The macro recall of  QUÝ : 0.861904761904762
# The macro recall of  NĂM : 0.9905660377358491
# Epoch: 4, Avg BLEU: 0.9678
# End of Epoch: 4
# Avg Train Loss: 0.0044
# Avg Val Loss: 0.0070
# Avg Val BLEU: 0.9678
# ##################################################
#
# Epoch: 5
# Epoch: 5, Train Loss: 0.0000, Avg Train Loss: 0.0035: 100% 4540/4540 [07:01<00:00, 10.78it/s]
# Epoch: 5, Avg Train Loss: 0.0035
# Epoch: 5, Eval Loss: 0.0063, Avg Eval Loss: 0.0056: 100% 568/568 [00:12<00:00, 46.71it/s]
# Epoch: 5, Avg Val Loss: 0.0056
# Epoch: 5, BLEU: 1.0000, Avg BLEU: 0.9793: 100% 568/568 [09:58<00:00,  1.05s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 568
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9981481481481481
# The macro recall of  ĐƠN VỊ : 0.9943840579710145
# The macro recall of  CHU KỲ THỜI GIAN : 0.9223109369760506
# The macro recall of  THỨ : 0.8546872022107872
# The macro recall of  NGÀY : 0.8360842900201517
# The macro recall of  TUẦN : 0.8309363455527139
# The macro recall of  THÁNG : 0.9824284248928774
# The macro recall of  QUÝ : 0.861904761904762
# The macro recall of  NĂM : 0.9904829191255923
# Epoch: 5, Avg BLEU: 0.9793
# Best BLEU model saved to ./output/vinai/bartpho-syllable-base
# End of Epoch: 5
# Avg Train Loss: 0.0035
# Avg Val Loss: 0.0056
# Avg Val BLEU: 0.9793
# ##################################################
#
# Epoch: 6
# Epoch: 6, Train Loss: 0.0001, Avg Train Loss: 0.0030: 100% 4540/4540 [07:03<00:00, 10.72it/s]
# Epoch: 6, Avg Train Loss: 0.0030
# Epoch: 6, Eval Loss: 0.0002, Avg Eval Loss: 0.0067: 100% 568/568 [00:12<00:00, 45.43it/s]
# Epoch: 6, Avg Val Loss: 0.0067
# Epoch: 6, BLEU: 1.0000, Avg BLEU: 0.9782: 100% 568/568 [10:14<00:00,  1.08s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 566
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9981481481481481
# The macro recall of  ĐƠN VỊ : 0.9925271739130435
# The macro recall of  CHU KỲ THỜI GIAN : 0.9020277231600886
# The macro recall of  THỨ : 0.8520501063264221
# The macro recall of  NGÀY : 0.7703665021344633
# The macro recall of  TUẦN : 0.8297550576324992
# The macro recall of  THÁNG : 0.9825059349252898
# The macro recall of  QUÝ : 0.861904761904762
# The macro recall of  NĂM : 0.9904825513441309
# Epoch: 6, Avg BLEU: 0.9782
# End of Epoch: 6
# Avg Train Loss: 0.0030
# Avg Val Loss: 0.0067
# Avg Val BLEU: 0.9782
# ##################################################
#
# Epoch: 7
# Epoch: 7, Train Loss: 0.0000, Avg Train Loss: 0.0020: 100% 4540/4540 [07:00<00:00, 10.79it/s]
# Epoch: 7, Avg Train Loss: 0.0020
# Epoch: 7, Eval Loss: 0.0001, Avg Eval Loss: 0.0070: 100% 568/568 [00:12<00:00, 45.69it/s]
# Epoch: 7, Avg Val Loss: 0.0070
# Epoch: 7, BLEU: 1.0000, Avg BLEU: 0.9723: 100% 568/568 [10:01<00:00,  1.06s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 566
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9981378026070763
# The macro recall of  ĐƠN VỊ : 0.9896519543258673
# The macro recall of  CHU KỲ THỜI GIAN : 0.8813217335780988
# The macro recall of  THỨ : 0.839628355927698
# The macro recall of  NGÀY : 0.728558337888437
# The macro recall of  TUẦN : 0.8559983198776363
# The macro recall of  THÁNG : 0.9755280713569812
# The macro recall of  QUÝ : 0.861904761904762
# The macro recall of  NĂM : 0.9810904244241742
# Epoch: 7, Avg BLEU: 0.9723
# End of Epoch: 7
# Avg Train Loss: 0.0020
# Avg Val Loss: 0.0070
# Avg Val BLEU: 0.9723
# ##################################################
#
# Epoch: 8
# Epoch: 8, Train Loss: 0.0000, Avg Train Loss: 0.0016: 100% 4540/4540 [07:02<00:00, 10.76it/s]
# Epoch: 8, Avg Train Loss: 0.0016
# Epoch: 8, Eval Loss: 0.0000, Avg Eval Loss: 0.0074: 100% 568/568 [00:11<00:00, 48.97it/s]
# Epoch: 8, Avg Val Loss: 0.0074
# Epoch: 8, BLEU: 1.0000, Avg BLEU: 0.9757: 100% 568/568 [09:56<00:00,  1.05s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 568
# The macro recall of  LOẠI BIỂU ĐỒ : 1.0
# The macro recall of  ĐƠN VỊ : 0.981521739130435
# The macro recall of  CHU KỲ THỜI GIAN : 0.8965440602883818
# The macro recall of  THỨ : 0.8845286592338479
# The macro recall of  NGÀY : 0.77028771756516
# The macro recall of  TUẦN : 0.8556188852352535
# The macro recall of  THÁNG : 0.9674284248928773
# The macro recall of  QUÝ : 0.8616966886629808
# The macro recall of  NĂM : 0.9810489568614413
# Epoch: 8, Avg BLEU: 0.9757
# End of Epoch: 8
# Avg Train Loss: 0.0016
# Avg Val Loss: 0.0074
# Avg Val BLEU: 0.9757
# ##################################################
#
# Epoch: 9
# Epoch: 9, Train Loss: 0.0000, Avg Train Loss: 0.0012: 100% 4540/4540 [07:00<00:00, 10.79it/s]
# Epoch: 9, Avg Train Loss: 0.0012
# Epoch: 9, Eval Loss: 0.0000, Avg Eval Loss: 0.0069: 100% 568/568 [00:11<00:00, 47.36it/s]
# Epoch: 9, Avg Val Loss: 0.0069
# Epoch: 9, BLEU: 1.0000, Avg BLEU: 0.9707: 100% 568/568 [09:56<00:00,  1.05s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 558
# The macro recall of  LOẠI BIỂU ĐỒ : 0.9981481481481481
# The macro recall of  ĐƠN VỊ : 0.993659420289855
# The macro recall of  CHU KỲ THỜI GIAN : 0.8673633976074491
# The macro recall of  THỨ : 0.8726132105314386
# The macro recall of  NGÀY : 0.8880128317464026
# The macro recall of  TUẦN : 0.8434037319674687
# The macro recall of  THÁNG : 0.9742552652781542
# The macro recall of  QUÝ : 0.861904761904762
# The macro recall of  NĂM : 0.9905660377358491
# Epoch: 9, Avg BLEU: 0.9707
# End of Epoch: 9
# Avg Train Loss: 0.0012
# Avg Val Loss: 0.0069
# Avg Val BLEU: 0.9707
# ##################################################
#
# Epoch: 10
# Epoch: 10, Train Loss: 0.0000, Avg Train Loss: 0.0008: 100% 4540/4540 [07:01<00:00, 10.76it/s]
# Epoch: 10, Avg Train Loss: 0.0008
# Epoch: 10, Eval Loss: 0.0001, Avg Eval Loss: 0.0098: 100% 568/568 [00:12<00:00, 46.05it/s]
# Epoch: 10, Avg Val Loss: 0.0098
# Epoch: 10, BLEU: 1.0000, Avg BLEU: 0.9763: 100% 568/568 [09:54<00:00,  1.05s/it]
# Input: hãy mở dashboard của viettel high tech 2009/3
# Output: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
# Target: "LOẠI BIỂU ĐỒ": "dashboard", "ĐƠN VỊ": "vnc", "CHU KỲ THỜI GIAN": "tháng", "THỨ": "khác", "NGÀY": "khác", "TUẦN": "khác", "THÁNG": "3", "QUÝ": "khác", "NĂM": "2009"
#
# Number of instances:  568
# Number of correct format instances: 568
# The macro recall of  LOẠI BIỂU ĐỒ : 1.0
# The macro recall of  ĐƠN VỊ : 0.9923007246376813
# The macro recall of  CHU KỲ THỜI GIAN : 0.8684179500029346
# The macro recall of  THỨ : 0.8781902158376215
# The macro recall of  NGÀY : 0.7664505785964619
# The macro recall of  TUẦN : 0.8532379328543012
# The macro recall of  THÁNG : 0.9822456763548657
# The macro recall of  QUÝ : 0.8773616312942156
# The macro recall of  NĂM : 0.9903166819050786
# Epoch: 10, Avg BLEU: 0.9763
# End of Epoch: 10
# Avg Train Loss: 0.0008
# Avg Val Loss: 0.0098
# Avg Val BLEU: 0.9763
# ##################################################
#
# Epoch: 11
# Epoch: 11, Train Loss: 0.0000, Avg Train Loss: 0.0006: 100% 4540/4540 [07:00<00:00, 10.81it/s]
# Epoch: 11, Avg Train Loss: 0.0006
# Epoch: 11, Eval Loss: 0.0000, Avg Eval Loss: 0.0091: 100% 568/568 [00:12<00:00, 45.20it/s]
# Epoch: 11, Avg Val Loss: 0.0091
# Epoch: 11, BLEU: 1.0000, Avg BLEU: 0.9788:   5% 28/568 [00:30<09:43,  1.08s/it]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/SystemRequest/Achatbot/text2table/train2.py", line 109, in <module>
#     avg_val_score = get_scores(val_dataloader, model, tokenizer, Config, epoch)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/drive/MyDrive/SystemRequest/Achatbot/text2table/utils.py", line 243, in get_scores
#     outputs = model.generate(
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py", line 1675, in generate
#     return self.beam_search(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py", line 3065, in beam_search
#     beam_outputs = beam_scorer.process(
#   File "/usr/local/lib/python3.10/dist-packages/transformers/generation/beam_search.py", line 251, in process
#     if self._done[batch_group_idx]:
# KeyboardInterrupt
# ^C

# %%
# !python text2table/train2.py --model_name facebook/mbart-large-50-many-to-many-mmt

# %%
# !git clone https://oauth2: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@github.com/TranXuanHuy267/SystemRequest.git
# Out:
# Cloning into 'SystemRequest'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (4/4), done.

# %%
os.chdir("/content/drive/MyDrive/SystemRequest")

# %%
# !git config --global user.email "huysntq@gmail.com"
# !git config --global user.name "TranXuanHuy267"
# !git add .
# !git commit -m "seven commit"
# !git push https://oauth2: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@github.com/TranXuanHuy267/SystemRequest.git
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 17 commits.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# remote: Invalid username or password.
# fatal: Authentication failed for 'https://github.com/TranXuanHuy267/SystemRequest.git/'
